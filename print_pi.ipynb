# %%
import numpy as np

print(np.pi)
# Out:
# 3.141592653589793

# %%
# !ls
# Out:
# BUILD.md     jupyterhub-proxy.pid      pytorch
# LICENSE      jupyterhub.ipynb	       scripts
# NEWS.md      jupyterhub.sqlite	       test_deeplearning.ipynb
# README.md    jupyterhub_config.py      ubuntu-xenial-16.04-cloudimg-console.log
# Vagrantfile  jupyterhub_cookie_secret  vagrant
# assets	     print_pi.ipynb

# %%
# !conda list anaconda
# Out:
# # packages in environment at /home/vagrant/.pyenv/versions/anaconda3-2020.07:
# #
# # Name                    Version                   Build  Channel
# anaconda                  2020.07                  py38_0
# anaconda-client           1.7.2                    py38_0
# anaconda-navigator        1.9.12                   py38_0
# anaconda-project          0.8.4                      py_0

# %%
# !conda list
# Out:
# # packages in environment at /home/vagrant/.pyenv/versions/anaconda3-2020.07:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0                    py38_0
# _libgcc_mutex             0.1                        main
# alabaster                 0.7.12                     py_0
# anaconda                  2020.07                  py38_0
# anaconda-client           1.7.2                    py38_0
# anaconda-navigator        1.9.12                   py38_0
# anaconda-project          0.8.4                      py_0
# argh                      0.26.2                   py38_0
# asn1crypto                1.3.0                    py38_0
# astroid                   2.4.2                    py38_0
# astropy                   4.0.1.post1      py38h7b6447c_1
# atomicwrites              1.4.0                      py_0
# attrs                     19.3.0                     py_0
# autopep8                  1.5.3                      py_0
# ...

# %%
# !env
# Out:
# TERM=xterm-color
# SHELL=/bin/bash
# MKL_THREADING_LAYER=INTEL
# CLICOLOR=1
# USER=vagrant
# KERNEL_LAUNCH_TIMEOUT=40
# JPY_PARENT_PID=28456
# PAGER=cat
# PATH=/home/vagrant/.pyenv/versions/anaconda3-2020.07/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/snap/bin
# PWD=/vagrant
# MPLBACKEND=module://ipykernel.pylab.backend_inline
# SHLVL=1
# HOME=/home/vagrant
# LOGNAME=vagrant
# LC_CTYPE=C.UTF-8
# GIT_PAGER=cat
# _=/usr/bin/env

# %%
! conda info
# Out:
#      active environment : None
#        user config file : /home/vagrant/.condarc
#  populated config files :
#           conda version : 4.8.3
#     conda-build version : 3.18.11
#          python version : 3.8.3.final.0
#        virtual packages : __glibc=2.23
#        base environment : /home/vagrant/.pyenv/versions/anaconda3-2020.07  (writable)
#            channel URLs : https://repo.anaconda.com/pkgs/main/linux-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/linux-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#           package cache : /home/vagrant/.pyenv/versions/anaconda3-2020.07/pkgs
#                           /home/vagrant/.conda/pkgs
#        envs directories : /home/vagrant/.pyenv/versions/anaconda3-2020.07/envs
#                           /home/vagrant/.conda/envs
#                platform : linux-64
# ...

# %%
# !conda --version
# Out:
# conda 4.8.3

# %%
# !conda -V
# Out:
# conda 4.8.3
