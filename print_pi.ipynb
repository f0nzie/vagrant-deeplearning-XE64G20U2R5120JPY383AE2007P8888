# %%
import numpy as np

print(np.pi)
# Out:
# 3.141592653589793

# %%
# !ls
# Out:
# assets			      print_pi.ipynb
# BUILD.md		      README.md
# jupyter-vagrant-box.markdown  scripts
# LICENSE			      ubuntu-xenial-16.04-cloudimg-console.log
# NEWS.md			      Vagrantfile

# %%
# !conda list
# Out:
# # packages in environment at /home/vagrant/.pyenv/versions/anaconda3-5.1.0:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0            py36he11e457_0
# alabaster                 0.7.10           py36h306e16b_0
# anaconda                  5.1.0                    py36_2
# anaconda-client           1.6.9                    py36_0
# anaconda-navigator        1.7.0                    py36_0
# anaconda-project          0.8.2            py36h44fb852_0
# asn1crypto                0.24.0                   py36_0
# astroid                   1.6.1                    py36_0
# astropy                   2.0.3            py36h14c3975_0
# attrs                     17.4.0                   py36_0
# babel                     2.5.3                    py36_0
# backports                 1.0              py36hfa02d7e_1
# backports.shutil_get_terminal_size 1.0.0            py36hfea85ff_2
# beautifulsoup4            4.6.0            py36h49b8c8c_1
# ...
